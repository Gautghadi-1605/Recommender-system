# %%
import numpy as np
import pandas as pd

# %%
movies=pd.read_csv('/content/movies.csv')

# %%
ratings=pd.read_csv('/content/ratings.csv')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
dataset=pd.merge(movies,ratings,on='movieId')

# %%
dataset.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946
# 3      15     2.5  1510577970
# 4      17     4.5  1305696483

# %%
dataset.groupby('title')['rating'].mean().head()
# Out:
# title
# '71 (2014)                                 4.0
# 'Hellboy': The Seeds of Creation (2004)    4.0
# 'Round Midnight (1986)                     3.5
# 'Salem's Lot (2004)                        5.0
# 'Til There Was You (1997)                  4.0
# Name: rating, dtype: float64

# %%
dataset.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# Gena the Crocodile (1969)              5.0
# True Stories (1986)                    5.0
# Cosmic Scrat-tastrophe (2015)          5.0
# Love and Pigeons (1985)                5.0
# Red Sorghum (Hong gao liang) (1987)    5.0
# Name: rating, dtype: float64

# %%
data=pd.DataFrame(dataset.groupby('title')['rating'].mean())

# %%
data
# Out:
#                                              rating
# title
# '71 (2014)                                 4.000000
# 'Hellboy': The Seeds of Creation (2004)    4.000000
# 'Round Midnight (1986)                     3.500000
# 'Salem's Lot (2004)                        5.000000
# 'Til There Was You (1997)                  4.000000
# ...                                             ...
# eXistenZ (1999)                            3.863636
# xXx (2002)                                 2.770833
# xXx: State of the Union (2005)             2.000000
# ¡Three Amigos! (1986)                      3.134615
# À nous la liberté (Freedom for Us) (1931)  1.000000
#
# [9719 rows x 1 columns]

# %%
data['rating count']=pd.DataFrame(dataset.groupby('title')['rating'].count())

# %%
data
# Out:
#                                              rating  rating count
# title
# '71 (2014)                                 4.000000             1
# 'Hellboy': The Seeds of Creation (2004)    4.000000             1
# 'Round Midnight (1986)                     3.500000             2
# 'Salem's Lot (2004)                        5.000000             1
# 'Til There Was You (1997)                  4.000000             2
# ...                                             ...           ...
# eXistenZ (1999)                            3.863636            22
# xXx (2002)                                 2.770833            24
# xXx: State of the Union (2005)             2.000000             5
# ¡Three Amigos! (1986)                      3.134615            26
# À nous la liberté (Freedom for Us) (1931)  1.000000             1
#
# [9719 rows x 2 columns]

# %%
data['rating']=round(data['rating'],1)

# %%
data
# Out:
#                                            rating  rating count
# title
# '71 (2014)                                    4.0             1
# 'Hellboy': The Seeds of Creation (2004)       4.0             1
# 'Round Midnight (1986)                        4.0             2
# 'Salem's Lot (2004)                           5.0             1
# 'Til There Was You (1997)                     4.0             2
# ...                                           ...           ...
# eXistenZ (1999)                               4.0            22
# xXx (2002)                                    3.0            24
# xXx: State of the Union (2005)                2.0             5
# ¡Three Amigos! (1986)                         3.0            26
# À nous la liberté (Freedom for Us) (1931)     1.0             1
#
# [9719 rows x 2 columns]

# %%
data[(data['rating']>3)& (data['rating count']>108)]
# Out:
#                                                     rating  rating count
# title
# 2001: A Space Odyssey (1968)                           4.0           109
# Aladdin (1992)                                         4.0           183
# Alien (1979)                                           4.0           146
# Aliens (1986)                                          4.0           126
# Amelie (Fabuleux destin d'Amélie Poulain, Le) (...     4.0           120
# ...                                                    ...           ...
# Truman Show, The (1998)                                4.0           125
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)              4.0           177
# Usual Suspects, The (1995)                             4.0           204
# Willy Wonka & the Chocolate Factory (1971)             4.0           119
# X-Men (2000)                                           4.0           133
#
# [89 rows x 2 columns]
